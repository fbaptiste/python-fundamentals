# %% [markdown]
# ### Instance Methods

# %% [markdown]
# We can create other instance methods. They work the same way as `__init__`, but don't get called automatically.

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius
        
    def area(self):
        print('area called...')

# %%
c = Circle(1)

# %%
c.radius
# Out:
# 1

# %% [markdown]
# So we have a circle with a radius of `1`, and we can also call the `area` method:

# %%
c.area()
# Out:
# area called...

# %% [markdown]
# The `self` paremter is automatically passed by Python, using whatever is to the **left** of the dot, so the instance `c` in this case.

# %% [markdown]
# Now, let's implement that `area` method:

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius
        
    def area(self):
        return math.pi * self.radius ** 2

# %% [markdown]
# You'll notice how we are accessing the `radius` attribute of the instance in the `area` instance method. Let's see how it works.

# %%
c = Circle(1)

# %%
c.radius
# Out:
# 1

# %%
c.area()
# Out:
# 3.141592653589793

# %% [markdown]
# So we can assign state to objects simply by setting attributes on the object, and we can implement functionality by creating instance methods.

# %% [markdown]
# These methods are just functions that end up being bound to the instance they are called "from", so we can specify additional paramters as well if we want to.

# %%
class Circle:
    def __init__(self, center_x, center_y, radius):
        self.center = (center_x, center_y)
        self.radius = radius
        
    def area(self):
        return math.pi * self.radius ** 2
    
    def translate(self, x, y):
        self.center = (self.center[0] + x, self.center[1] + y)
        
    def scale(self, factor):
        self.radius = self.radius * factor

# %%
c = Circle(0, 0, 2)

# %%
c.center
# Out:
# (0, 0)

# %%
c.radius
# Out:
# 2

# %%
c.translate(1, 2)

# %%
c.center
# Out:
# (1, 2)

# %%
c.radius
# Out:
# 2

# %%
c.scale(3)

# %%
c.radius
# Out:
# 6

# %% [markdown]
# Now we know how to create and initialize classes, as well as implement methods that can be used to calculate things, or even modify the internal state of the object.

# %% [markdown]
# This allows us to "package" up related functionality neatly in custom classes. (This is called *encapsulation*)

# %% [markdown]
# For example, we looked at an example earlier that loaded forex data from a text file:

# %%
file_name = 'DEXUSEU.csv'

# %%
with open(file_name) as f:
    for _ in range(5):
        print(next(f))
# Out:
# DATE,DEXUSEU
#
# 2015-04-03,1.0990
#
# 2015-04-06,1.1008
#
# 2015-04-07,1.0850
#
# 2015-04-08,1.0818

# %% [markdown]
# We ended up writing some code to load the data up. We're going to do the same thing here, but we'll also want to provide the data parsed into `datetime` and `Decimal` objects, as well as provide the headers of the data.

# %% [markdown]
# Let's just write some simple scripts first to see how we can start tackling this problem.

# %% [markdown]
# First we have to load the data, so we'll use the `csv` module for that:

# %%
import csv

# %%
with open(file_name) as f:
    reader = csv.reader(f)
    
    headers = next(reader)
    
    data = list(reader)

# %%
print(headers)
# Out:
# ['DATE', 'DEXUSEU']

# %%
print(data[:5])
# Out:
# [['2015-04-03', '1.0990'], ['2015-04-06', '1.1008'], ['2015-04-07', '1.0850'], ['2015-04-08', '1.0818'], ['2015-04-09', '1.0671']]

# %% [markdown]
# We will want to parse the dates into `date` objects, for that we'll use the `strptime` function:

# %%
from datetime import datetime

# %%
datetime.strptime('2015-04-03', '%Y-%m-%d').date()
# Out:
# datetime.date(2015, 4, 3)

# %% [markdown]
# Also, we'll want to use `Decimal` objects for the values:

# %%
from decimal import Decimal

# %%
Decimal('1.0990')
# Out:
# Decimal('1.0990')

# %% [markdown]
# Ok, now we have all the pieces we need, let's start packaging this up into a class:

# %%
class Forex:
    def __init__(self, file_name):
        with open(file_name) as f:
            reader = csv.reader(f)
            
            self.headers = next(reader)
            self.data = list(reader)

# %%
forex = Forex(file_name)

# %%
forex.headers
# Out:
# ['DATE', 'DEXUSEU']

# %%
forex.data
# Out:
# [['2015-04-03', '1.0990'],
#  ['2015-04-06', '1.1008'],
#  ['2015-04-07', '1.0850'],
#  ['2015-04-08', '1.0818'],
#  ['2015-04-09', '1.0671'],
#  ['2015-04-10', '1.0598'],
#  ['2015-04-13', '1.0582'],
#  ['2015-04-14', '1.0672'],
#  ['2015-04-15', '1.0596'],
#  ['2015-04-16', '1.0742'],
#  ['2015-04-17', '1.0780'],
#  ['2015-04-20', '1.0763'],
#  ['2015-04-21', '1.0758'],
#  ['2015-04-22', '1.0729'],
#  ['2015-04-23', '1.0803'],
#  ['2015-04-24', '1.0876'],
#  ['2015-04-27', '1.0892'],
#  ['2015-04-28', '1.0979'],
#  ['2015-04-29', '1.1174'],
#  ['2015-04-30', '1.1162'],
#  ['2015-05-01', '1.1194'],
#  ['2015-05-04', '1.1145'],
#  ['2015-05-05', '1.1174'],
#  ['2015-05-06', '1.1345'],
#  ['2015-05-07', '1.1283'],
#  ['2015-05-08', '1.1241'],
#  ['2015-05-11', '1.1142'],
#  ['2015-05-12', '1.1240'],
#  ['2015-05-13', '1.1372'],
#  ['2015-05-14', '1.1368'],
#  ['2015-05-15', '1.1428'],
#  ['2015-05-18', '1.1354'],
#  ['2015-05-19', '1.1151'],
#  ['2015-05-20', '1.1079'],
#  ['2015-05-21', '1.1126'],
#  ['2015-05-22', '1.1033'],
#  ['2015-05-25', '.'],
#  ['2015-05-26', '1.0876'],
#  ['2015-05-27', '1.0888'],
#  ['2015-05-28', '1.0914'],
#  ['2015-05-29', '1.0994'],
#  ['2015-06-01', '1.0913'],
#  ['2015-06-02', '1.1130'],
#  ['2015-06-03', '1.1285'],
#  ['2015-06-04', '1.1271'],
#  ['2015-06-05', '1.1108'],
#  ['2015-06-08', '1.1232'],
#  ['2015-06-09', '1.1284'],
#  ['2015-06-10', '1.1307'],
#  ['2015-06-11', '1.1236'],
#  ['2015-06-12', '1.1278'],
#  ['2015-06-15', '1.1266'],
#  ['2015-06-16', '1.1238'],
#  ['2015-06-17', '1.1244'],
#  ['2015-06-18', '1.1404'],
#  ['2015-06-19', '1.1335'],
#  ['2015-06-22', '1.1378'],
#  ['2015-06-23', '1.1190'],
#  ['2015-06-24', '1.1178'],
#  ['2015-06-25', '1.1196'],
#  ['2015-06-26', '1.1156'],
#  ['2015-06-29', '1.1180'],
#  ['2015-06-30', '1.1154'],
#  ['2015-07-01', '1.1084'],
#  ['2015-07-02', '1.1090'],
#  ['2015-07-03', '.'],
#  ['2015-07-06', '1.1076'],
#  ['2015-07-07', '1.0952'],
#  ['2015-07-08', '1.1072'],
#  ['2015-07-09', '1.1025'],
#  ['2015-07-10', '1.1150'],
#  ['2015-07-13', '1.1020'],
#  ['2015-07-14', '1.1015'],
#  ['2015-07-15', '1.0965'],
#  ['2015-07-16', '1.0898'],
#  ['2015-07-17', '1.0848'],
#  ['2015-07-20', '1.0850'],
#  ['2015-07-21', '1.0927'],
#  ['2015-07-22', '1.0884'],
#  ['2015-07-23', '1.0976'],
#  ['2015-07-24', '1.0976'],
#  ['2015-07-27', '1.1112'],
#  ['2015-07-28', '1.1055'],
#  ['2015-07-29', '1.1026'],
#  ['2015-07-30', '1.0914'],
#  ['2015-07-31', '1.1028'],
#  ['2015-08-03', '1.0962'],
#  ['2015-08-04', '1.0953'],
#  ['2015-08-05', '1.0868'],
#  ['2015-08-06', '1.0922'],
#  ['2015-08-07', '1.0958'],
#  ['2015-08-10', '1.0994'],
#  ['2015-08-11', '1.1042'],
#  ['2015-08-12', '1.1198'],
#  ['2015-08-13', '1.1144'],
#  ['2015-08-14', '1.1110'],
#  ['2015-08-17', '1.1078'],
#  ['2015-08-18', '1.1028'],
#  ['2015-08-19', '1.1061'],
#  ['2015-08-20', '1.1200'],
#  ['2015-08-21', '1.1356'],
#  ['2015-08-24', '1.1580'],
#  ['2015-08-25', '1.1410'],
#  ['2015-08-26', '1.1390'],
#  ['2015-08-27', '1.1239'],
#  ['2015-08-28', '1.1172'],
#  ['2015-08-31', '1.1194'],
#  ['2015-09-01', '1.1263'],
#  ['2015-09-02', '1.1242'],
#  ['2015-09-03', '1.1104'],
#  ['2015-09-04', '1.1117'],
#  ['2015-09-07', '.'],
#  ['2015-09-08', '1.1182'],
#  ['2015-09-09', '1.1165'],
#  ['2015-09-10', '1.1262'],
#  ['2015-09-11', '1.1338'],
#  ['2015-09-14', '1.1307'],
#  ['2015-09-15', '1.1260'],
#  ['2015-09-16', '1.1304'],
#  ['2015-09-17', '1.1312'],
#  ['2015-09-18', '1.1358'],
#  ['2015-09-21', '1.1204'],
#  ['2015-09-22', '1.1133'],
#  ['2015-09-23', '1.1160'],
#  ['2015-09-24', '1.1252'],
#  ['2015-09-25', '1.1192'],
#  ['2015-09-28', '1.1236'],
#  ['2015-09-29', '1.1246'],
#  ['2015-09-30', '1.1162'],
#  ['2015-10-01', '1.1200'],
#  ['2015-10-02', '1.1276'],
#  ['2015-10-05', '1.1200'],
#  ['2015-10-06', '1.1266'],
#  ['2015-10-07', '1.1249'],
#  ['2015-10-08', '1.1282'],
#  ['2015-10-09', '1.1363'],
#  ['2015-10-12', '.'],
#  ['2015-10-13', '1.1382'],
#  ['2015-10-14', '1.1437'],
#  ['2015-10-15', '1.1418'],
#  ['2015-10-16', '1.1360'],
#  ['2015-10-19', '1.1320'],
#  ['2015-10-20', '1.1359'],
#  ['2015-10-21', '1.1345'],
#  ['2015-10-22', '1.1140'],
#  ['2015-10-23', '1.1016'],
#  ['2015-10-26', '1.1051'],
#  ['2015-10-27', '1.1052'],
#  ['2015-10-28', '1.1066'],
#  ['2015-10-29', '1.0963'],
#  ['2015-10-30', '1.1042'],
#  ['2015-11-02', '1.1026'],
#  ['2015-11-03', '1.0946'],
#  ['2015-11-04', '1.0861'],
#  ['2015-11-05', '1.0869'],
#  ['2015-11-06', '1.0746'],
#  ['2015-11-09', '1.0767'],
#  ['2015-11-10', '1.0686'],
#  ['2015-11-11', '.'],
#  ['2015-11-12', '1.0768'],
#  ['2015-11-13', '1.0722'],
#  ['2015-11-16', '1.0708'],
#  ['2015-11-17', '1.0634'],
#  ['2015-11-18', '1.0638'],
#  ['2015-11-19', '1.0746'],
#  ['2015-11-20', '1.0660'],
#  ['2015-11-23', '1.0602'],
#  ['2015-11-24', '1.0652'],
#  ['2015-11-25', '1.0616'],
#  ['2015-11-26', '.'],
#  ['2015-11-27', '1.0596'],
#  ['2015-11-30', '1.0562'],
#  ['2015-12-01', '1.0620'],
#  ['2015-12-02', '1.0573'],
#  ['2015-12-03', '1.0902'],
#  ['2015-12-04', '1.0884'],
#  ['2015-12-07', '1.0840'],
#  ['2015-12-08', '1.0876'],
#  ['2015-12-09', '1.0984'],
#  ['2015-12-10', '1.0948'],
#  ['2015-12-11', '1.1002'],
#  ['2015-12-14', '1.1025'],
#  ['2015-12-15', '1.0911'],
#  ['2015-12-16', '1.0937'],
#  ['2015-12-17', '1.0804'],
#  ['2015-12-18', '1.0847'],
#  ['2015-12-21', '1.0920'],
#  ['2015-12-22', '1.0978'],
#  ['2015-12-23', '1.0875'],
#  ['2015-12-24', '1.0955'],
#  ['2015-12-25', '.'],
#  ['2015-12-28', '1.0983'],
#  ['2015-12-29', '1.0916'],
#  ['2015-12-30', '1.0912'],
#  ['2015-12-31', '1.0859'],
#  ['2016-01-01', '.'],
#  ['2016-01-04', '1.0803'],
#  ['2016-01-05', '1.0743'],
#  ['2016-01-06', '1.0762'],
#  ['2016-01-07', '1.0860'],
#  ['2016-01-08', '1.0885'],
#  ['2016-01-11', '1.0878'],
#  ['2016-01-12', '1.0837'],
#  ['2016-01-13', '1.0862'],
#  ['2016-01-14', '1.0862'],
#  ['2016-01-15', '1.0964'],
#  ['2016-01-18', '.'],
#  ['2016-01-19', '1.0906'],
#  ['2016-01-20', '1.0908'],
#  ['2016-01-21', '1.0833'],
#  ['2016-01-22', '1.0814'],
#  ['2016-01-25', '1.0832'],
#  ['2016-01-26', '1.0846'],
#  ['2016-01-27', '1.0867'],
#  ['2016-01-28', '1.0952'],
#  ['2016-01-29', '1.0832'],
#  ['2016-02-01', '1.0888'],
#  ['2016-02-02', '1.0908'],
#  ['2016-02-03', '1.1051'],
#  ['2016-02-04', '1.1199'],
#  ['2016-02-05', '1.1131'],
#  ['2016-02-08', '1.1170'],
#  ['2016-02-09', '1.1300'],
#  ['2016-02-10', '1.1222'],
#  ['2016-02-11', '1.1362'],
#  ['2016-02-12', '1.1235'],
#  ['2016-02-15', '.'],
#  ['2016-02-16', '1.1140'],
#  ['2016-02-17', '1.1140'],
#  ['2016-02-18', '1.1092'],
#  ['2016-02-19', '1.1127'],
#  ['2016-02-22', '1.1018'],
#  ['2016-02-23', '1.1016'],
#  ['2016-02-24', '1.1021'],
#  ['2016-02-25', '1.1026'],
#  ['2016-02-26', '1.0932'],
#  ['2016-02-29', '1.0868'],
#  ['2016-03-01', '1.0847'],
#  ['2016-03-02', '1.0845'],
#  ['2016-03-03', '1.0948'],
#  ['2016-03-04', '1.1010'],
#  ['2016-03-07', '1.1004'],
#  ['2016-03-08', '1.1028'],
#  ['2016-03-09', '1.1022'],
#  ['2016-03-10', '1.1162'],
#  ['2016-03-11', '1.1180'],
#  ['2016-03-14', '1.1107'],
#  ['2016-03-15', '1.1112'],
#  ['2016-03-16', '1.1075'],
#  ['2016-03-17', '1.1316'],
#  ['2016-03-18', '1.1292'],
#  ['2016-03-21', '1.1260'],
#  ['2016-03-22', '1.1228'],
#  ['2016-03-23', '1.1174'],
#  ['2016-03-24', '1.1163'],
#  ['2016-03-25', '1.1164'],
#  ['2016-03-28', '1.1210'],
#  ['2016-03-29', '1.1204'],
#  ['2016-03-30', '1.1330'],
#  ['2016-03-31', '1.1390'],
#  ['2016-04-01', '1.1385'],
#  ['2016-04-04', '1.1386'],
#  ['2016-04-05', '1.1374'],
#  ['2016-04-06', '1.1430'],
#  ['2016-04-07', '1.1386'],
#  ['2016-04-08', '1.1406'],
#  ['2016-04-11', '1.1412'],
#  ['2016-04-12', '1.1395'],
#  ['2016-04-13', '1.1281'],
#  ['2016-04-14', '1.1262'],
#  ['2016-04-15', '1.1295'],
#  ['2016-04-18', '1.1322'],
#  ['2016-04-19', '1.1375'],
#  ['2016-04-20', '1.1330'],
#  ['2016-04-21', '1.1301'],
#  ['2016-04-22', '1.1239'],
#  ['2016-04-25', '1.1274'],
#  ['2016-04-26', '1.1318'],
#  ['2016-04-27', '1.1322'],
#  ['2016-04-28', '1.1325'],
#  ['2016-04-29', '1.1441'],
#  ['2016-05-02', '1.1516'],
#  ['2016-05-03', '1.1508'],
#  ['2016-05-04', '1.1486'],
#  ['2016-05-05', '1.1404'],
#  ['2016-05-06', '1.1421'],
#  ['2016-05-09', '1.1402'],
#  ['2016-05-10', '1.1386'],
#  ['2016-05-11', '1.1444'],
#  ['2016-05-12', '1.1380'],
#  ['2016-05-13', '1.1294'],
#  ['2016-05-16', '1.1328'],
#  ['2016-05-17', '1.1337'],
#  ['2016-05-18', '1.1276'],
#  ['2016-05-19', '1.1214'],
#  ['2016-05-20', '1.1207'],
#  ['2016-05-23', '1.1192'],
#  ['2016-05-24', '1.1145'],
#  ['2016-05-25', '1.1154'],
#  ['2016-05-26', '1.1184'],
#  ['2016-05-27', '1.1140'],
#  ['2016-05-30', '.'],
#  ['2016-05-31', '1.1135'],
#  ['2016-06-01', '1.1165'],
#  ['2016-06-02', '1.1157'],
#  ['2016-06-03', '1.1330'],
#  ['2016-06-06', '1.1354'],
#  ['2016-06-07', '1.1350'],
#  ['2016-06-08', '1.1400'],
#  ['2016-06-09', '1.1329'],
#  ['2016-06-10', '1.1281'],
#  ['2016-06-13', '1.1282'],
#  ['2016-06-14', '1.1206'],
#  ['2016-06-15', '1.1239'],
#  ['2016-06-16', '1.1158'],
#  ['2016-06-17', '1.1256'],
#  ['2016-06-20', '1.1318'],
#  ['2016-06-21', '1.1262'],
#  ['2016-06-22', '1.1286'],
#  ['2016-06-23', '1.1373'],
#  ['2016-06-24', '1.1126'],
#  ['2016-06-27', '1.1024'],
#  ['2016-06-28', '1.1054'],
#  ['2016-06-29', '1.1117'],
#  ['2016-06-30', '1.1032'],
#  ['2016-07-01', '1.1145'],
#  ['2016-07-04', '.'],
#  ['2016-07-05', '1.1080'],
#  ['2016-07-06', '1.1077'],
#  ['2016-07-07', '1.1065'],
#  ['2016-07-08', '1.1038'],
#  ['2016-07-11', '1.1045'],
#  ['2016-07-12', '1.1074'],
#  ['2016-07-13', '1.1112'],
#  ['2016-07-14', '1.1109'],
#  ['2016-07-15', '1.1059'],
#  ['2016-07-18', '1.1076'],
#  ['2016-07-19', '1.1014'],
#  ['2016-07-20', '1.1007'],
#  ['2016-07-21', '1.1016'],
#  ['2016-07-22', '1.0968'],
#  ['2016-07-25', '1.0980'],
#  ['2016-07-26', '1.0984'],
#  ['2016-07-27', '1.0988'],
#  ['2016-07-28', '1.1094'],
#  ['2016-07-29', '1.1168'],
#  ['2016-08-01', '1.1176'],
#  ['2016-08-02', '1.1225'],
#  ['2016-08-03', '1.1170'],
#  ['2016-08-04', '1.1134'],
#  ['2016-08-05', '1.1080'],
#  ['2016-08-08', '1.1078'],
#  ['2016-08-09', '1.1110'],
#  ['2016-08-10', '1.1171'],
#  ['2016-08-11', '1.1168'],
#  ['2016-08-12', '1.1172'],
#  ['2016-08-15', '1.1199'],
#  ['2016-08-16', '1.1277'],
#  ['2016-08-17', '1.1263'],
#  ['2016-08-18', '1.1334'],
#  ['2016-08-19', '1.1326'],
#  ['2016-08-22', '1.1314'],
#  ['2016-08-23', '1.1308'],
#  ['2016-08-24', '1.1256'],
#  ['2016-08-25', '1.1274'],
#  ['2016-08-26', '1.1237'],
#  ['2016-08-29', '1.1182'],
#  ['2016-08-30', '1.1150'],
#  ['2016-08-31', '1.1146'],
#  ['2016-09-01', '1.1194'],
#  ['2016-09-02', '1.1158'],
#  ['2016-09-05', '.'],
#  ['2016-09-06', '1.1237'],
#  ['2016-09-07', '1.1238'],
#  ['2016-09-08', '1.1256'],
#  ['2016-09-09', '1.1214'],
#  ['2016-09-12', '1.1230'],
#  ['2016-09-13', '1.1242'],
#  ['2016-09-14', '1.1271'],
#  ['2016-09-15', '1.1246'],
#  ['2016-09-16', '1.1160'],
#  ['2016-09-19', '1.1179'],
#  ['2016-09-20', '1.1172'],
#  ['2016-09-21', '1.1165'],
#  ['2016-09-22', '1.1229'],
#  ['2016-09-23', '1.1223'],
#  ['2016-09-26', '1.1270'],
#  ['2016-09-27', '1.1208'],
#  ['2016-09-28', '1.1200'],
#  ['2016-09-29', '1.1244'],
#  ['2016-09-30', '1.1238'],
#  ['2016-10-03', '1.1210'],
#  ['2016-10-04', '1.1212'],
#  ['2016-10-05', '1.1196'],
#  ['2016-10-06', '1.1158'],
#  ['2016-10-07', '1.1156'],
#  ['2016-10-10', '.'],
#  ['2016-10-11', '1.1062'],
#  ['2016-10-12', '1.1014'],
#  ['2016-10-13', '1.1038'],
#  ['2016-10-14', '1.0985'],
#  ['2016-10-17', '1.1000'],
#  ['2016-10-18', '1.0997'],
#  ['2016-10-19', '1.0966'],
#  ['2016-10-20', '1.0934'],
#  ['2016-10-21', '1.0866'],
#  ['2016-10-24', '1.0888'],
#  ['2016-10-25', '1.0890'],
#  ['2016-10-26', '1.0916'],
#  ['2016-10-27', '1.0904'],
#  ['2016-10-28', '1.0934'],
#  ['2016-10-31', '1.0962'],
#  ['2016-11-01', '1.1042'],
#  ['2016-11-02', '1.1119'],
#  ['2016-11-03', '1.1094'],
#  ['2016-11-04', '1.1121'],
#  ['2016-11-07', '1.1038'],
#  ['2016-11-08', '1.1034'],
#  ['2016-11-09', '1.0952'],
#  ['2016-11-10', '1.0882'],
#  ['2016-11-11', '.'],
#  ['2016-11-14', '1.0723'],
#  ['2016-11-15', '1.0726'],
#  ['2016-11-16', '1.0699'],
#  ['2016-11-17', '1.0656'],
#  ['2016-11-18', '1.0600'],
#  ['2016-11-21', '1.0597'],
#  ['2016-11-22', '1.0618'],
#  ['2016-11-23', '1.0560'],
#  ['2016-11-24', '.'],
#  ['2016-11-25', '1.0595'],
#  ['2016-11-28', '1.0576'],
#  ['2016-11-29', '1.0626'],
#  ['2016-11-30', '1.0578'],
#  ['2016-12-01', '1.0634'],
#  ['2016-12-02', '1.0666'],
#  ['2016-12-05', '1.0723'],
#  ['2016-12-06', '1.0717'],
#  ['2016-12-07', '1.0758'],
#  ['2016-12-08', '1.0625'],
#  ['2016-12-09', '1.0541'],
#  ['2016-12-12', '1.0606'],
#  ['2016-12-13', '1.0635'],
#  ['2016-12-14', '1.0656'],
#  ['2016-12-15', '1.0375'],
#  ['2016-12-16', '1.0456'],
#  ['2016-12-19', '1.0444'],
#  ['2016-12-20', '1.0390'],
#  ['2016-12-21', '1.0425'],
#  ['2016-12-22', '1.0452'],
#  ['2016-12-23', '1.0449'],
#  ['2016-12-26', '.'],
#  ['2016-12-27', '1.0458'],
#  ['2016-12-28', '1.0389'],
#  ['2016-12-29', '1.0486'],
#  ['2016-12-30', '1.0552'],
#  ['2017-01-02', '.'],
#  ['2017-01-03', '1.0416'],
#  ['2017-01-04', '1.0476'],
#  ['2017-01-05', '1.0598'],
#  ['2017-01-06', '1.0560'],
#  ['2017-01-09', '1.0576'],
#  ['2017-01-10', '1.0572'],
#  ['2017-01-11', '1.0501'],
#  ['2017-01-12', '1.0666'],
#  ['2017-01-13', '1.0625'],
#  ['2017-01-16', '.'],
#  ['2017-01-17', '1.0695'],
#  ['2017-01-18', '1.0682'],
#  ['2017-01-19', '1.0630'],
#  ['2017-01-20', '.'],
#  ['2017-01-23', '1.0740'],
#  ['2017-01-24', '1.0749'],
#  ['2017-01-25', '1.0743'],
#  ['2017-01-26', '1.0670'],
#  ['2017-01-27', '1.0690'],
#  ['2017-01-30', '1.0681'],
#  ['2017-01-31', '1.0794'],
#  ['2017-02-01', '1.0758'],
#  ['2017-02-02', '1.0802'],
#  ['2017-02-03', '1.0792'],
#  ['2017-02-06', '1.0731'],
#  ['2017-02-07', '1.0690'],
#  ['2017-02-08', '1.0708'],
#  ['2017-02-09', '1.0658'],
#  ['2017-02-10', '1.0650'],
#  ['2017-02-13', '1.0603'],
#  ['2017-02-14', '1.0577'],
#  ['2017-02-15', '1.0597'],
#  ['2017-02-16', '1.0660'],
#  ['2017-02-17', '1.0614'],
#  ['2017-02-20', '.'],
#  ['2017-02-21', '1.0551'],
#  ['2017-02-22', '1.0555'],
#  ['2017-02-23', '1.0586'],
#  ['2017-02-24', '1.0580'],
#  ['2017-02-27', '1.0624'],
#  ['2017-02-28', '1.0618'],
#  ['2017-03-01', '1.0564'],
#  ['2017-03-02', '1.0514'],
#  ['2017-03-03', '1.0552'],
#  ['2017-03-06', '1.0586'],
#  ['2017-03-07', '1.0582'],
#  ['2017-03-08', '1.0547'],
#  ['2017-03-09', '1.0586'],
#  ['2017-03-10', '1.0667'],
#  ['2017-03-13', '1.0670'],
#  ['2017-03-14', '1.0645'],
#  ['2017-03-15', '1.0630'],
#  ['2017-03-16', '1.0738'],
#  ['2017-03-17', '1.0742'],
#  ['2017-03-20', '1.0754'],
#  ['2017-03-21', '1.0810'],
#  ['2017-03-22', '1.0800'],
#  ['2017-03-23', '1.0787'],
#  ['2017-03-24', '1.0806'],
#  ['2017-03-27', '1.0882'],
#  ['2017-03-28', '1.0852'],
#  ['2017-03-29', '1.0756'],
#  ['2017-03-30', '1.0726'],
#  ['2017-03-31', '1.0698'],
#  ['2017-04-03', '1.0655'],
#  ['2017-04-04', '1.0664'],
#  ['2017-04-05', '1.0661'],
#  ['2017-04-06', '1.0651'],
#  ['2017-04-07', '1.0616'],
#  ['2017-04-10', '1.0606'],
#  ['2017-04-11', '1.0614'],
#  ['2017-04-12', '1.0611'],
#  ['2017-04-13', '1.0630'],
#  ['2017-04-14', '1.0625'],
#  ['2017-04-17', '1.0660'],
#  ['2017-04-18', '1.0706'],
#  ['2017-04-19', '1.0707'],
#  ['2017-04-20', '1.0758'],
#  ['2017-04-21', '1.0694'],
#  ['2017-04-24', '1.0846'],
#  ['2017-04-25', '1.0941'],
#  ['2017-04-26', '1.0872'],
#  ['2017-04-27', '1.0864'],
#  ['2017-04-28', '1.0895'],
#  ['2017-05-01', '1.0912'],
#  ['2017-05-02', '1.0910'],
#  ['2017-05-03', '1.0920'],
#  ['2017-05-04', '1.0967'],
#  ['2017-05-05', '1.0996'],
#  ['2017-05-08', '1.0928'],
#  ['2017-05-09', '1.0875'],
#  ['2017-05-10', '1.0873'],
#  ['2017-05-11', '1.0869'],
#  ['2017-05-12', '1.0926'],
#  ['2017-05-15', '1.0979'],
#  ['2017-05-16', '1.1072'],
#  ['2017-05-17', '1.1134'],
#  ['2017-05-18', '1.1130'],
#  ['2017-05-19', '1.1190'],
#  ['2017-05-22', '1.1236'],
#  ['2017-05-23', '1.1198'],
#  ['2017-05-24', '1.1175'],
#  ['2017-05-25', '1.1218'],
#  ['2017-05-26', '1.1170'],
#  ['2017-05-29', '.'],
#  ['2017-05-30', '1.1183'],
#  ['2017-05-31', '1.1236'],
#  ['2017-06-01', '1.1214'],
#  ['2017-06-02', '1.1270'],
#  ['2017-06-05', '1.1250'],
#  ['2017-06-06', '1.1266'],
#  ['2017-06-07', '1.1236'],
#  ['2017-06-08', '1.1217'],
#  ['2017-06-09', '1.1190'],
#  ['2017-06-12', '1.1204'],
#  ['2017-06-13', '1.1194'],
#  ['2017-06-14', '1.1277'],
#  ['2017-06-15', '1.1152'],
#  ['2017-06-16', '1.1194'],
#  ['2017-06-19', '1.1160'],
#  ['2017-06-20', '1.1124'],
#  ['2017-06-21', '1.1143'],
#  ['2017-06-22', '1.1148'],
#  ['2017-06-23', '1.1196'],
#  ['2017-06-26', '1.1196'],
#  ['2017-06-27', '1.1300'],
#  ['2017-06-28', '1.1364'],
#  ['2017-06-29', '1.1420'],
#  ['2017-06-30', '1.1411'],
#  ['2017-07-03', '1.1367'],
#  ['2017-07-04', '.'],
#  ['2017-07-05', '1.1336'],
#  ['2017-07-06', '1.1409'],
#  ['2017-07-07', '1.1396'],
#  ['2017-07-10', '1.1396'],
#  ['2017-07-11', '1.1430'],
#  ['2017-07-12', '1.1411'],
#  ['2017-07-13', '1.1385'],
#  ['2017-07-14', '1.1452'],
#  ['2017-07-17', '1.1470'],
#  ['2017-07-18', '1.1578'],
#  ['2017-07-19', '1.1518'],
#  ['2017-07-20', '1.1634'],
#  ['2017-07-21', '1.1655'],
#  ['2017-07-24', '1.1642'],
#  ['2017-07-25', '1.1656'],
#  ['2017-07-26', '1.1632'],
#  ['2017-07-27', '1.1656'],
#  ['2017-07-28', '1.1754'],
#  ['2017-07-31', '1.1826'],
#  ['2017-08-01', '1.1799'],
#  ['2017-08-02', '1.1861'],
#  ['2017-08-03', '1.1880'],
#  ['2017-08-04', '1.1754'],
#  ['2017-08-07', '1.1788'],
#  ['2017-08-08', '1.1724'],
#  ['2017-08-09', '1.1748'],
#  ['2017-08-10', '1.1751'],
#  ['2017-08-11', '1.1811'],
#  ['2017-08-14', '1.1786'],
#  ['2017-08-15', '1.1736'],
#  ['2017-08-16', '1.1703'],
#  ['2017-08-17', '1.1736'],
#  ['2017-08-18', '1.1748'],
#  ['2017-08-21', '1.1814'],
#  ['2017-08-22', '1.1762'],
#  ['2017-08-23', '1.1802'],
#  ['2017-08-24', '1.1801'],
#  ['2017-08-25', '1.1874'],
#  ['2017-08-28', '1.1973'],
#  ['2017-08-29', '1.2025'],
#  ['2017-08-30', '1.1927'],
#  ['2017-08-31', '1.1894'],
#  ['2017-09-01', '1.1878'],
#  ['2017-09-04', '.'],
#  ['2017-09-05', '1.1911'],
#  ['2017-09-06', '1.1943'],
#  ['2017-09-07', '1.2028'],
#  ['2017-09-08', '1.2041'],
#  ['2017-09-11', '1.1964'],
#  ['2017-09-12', '1.1968'],
#  ['2017-09-13', '1.1898'],
#  ['2017-09-14', '1.1886'],
#  ['2017-09-15', '1.1959'],
#  ['2017-09-18', '1.1938'],
#  ['2017-09-19', '1.1980'],
#  ['2017-09-20', '1.1998'],
#  ['2017-09-21', '1.1946'],
#  ['2017-09-22', '1.1969'],
#  ['2017-09-25', '1.1852'],
#  ['2017-09-26', '1.1772'],
#  ['2017-09-27', '1.1747'],
#  ['2017-09-28', '1.1776'],
#  ['2017-09-29', '1.1813'],
#  ['2017-10-02', '1.1745'],
#  ['2017-10-03', '1.1759'],
#  ['2017-10-04', '1.1760'],
#  ['2017-10-05', '1.1706'],
#  ['2017-10-06', '1.1732'],
#  ['2017-10-09', '.'],
#  ['2017-10-10', '1.1804'],
#  ['2017-10-11', '1.1847'],
#  ['2017-10-12', '1.1840'],
#  ['2017-10-13', '1.1837'],
#  ['2017-10-16', '1.1810'],
#  ['2017-10-17', '1.1754'],
#  ['2017-10-18', '1.1775'],
#  ['2017-10-19', '1.1842'],
#  ['2017-10-20', '1.1770'],
#  ['2017-10-23', '1.1762'],
#  ['2017-10-24', '1.1766'],
#  ['2017-10-25', '1.1802'],
#  ['2017-10-26', '1.1700'],
#  ['2017-10-27', '1.1580'],
#  ['2017-10-30', '1.1626'],
#  ['2017-10-31', '1.1648'],
#  ['2017-11-01', '1.1618'],
#  ['2017-11-02', '1.1672'],
#  ['2017-11-03', '1.1616'],
#  ['2017-11-06', '1.1600'],
#  ['2017-11-07', '1.1577'],
#  ['2017-11-08', '1.1591'],
#  ['2017-11-09', '1.1648'],
#  ['2017-11-10', '.'],
#  ['2017-11-13', '1.1656'],
#  ['2017-11-14', '1.1764'],
#  ['2017-11-15', '1.1794'],
#  ['2017-11-16', '1.1772'],
#  ['2017-11-17', '1.1799'],
#  ['2017-11-20', '1.1741'],
#  ['2017-11-21', '1.1741'],
#  ['2017-11-22', '1.1789'],
#  ['2017-11-23', '.'],
#  ['2017-11-24', '1.1936'],
#  ['2017-11-27', '1.1911'],
#  ['2017-11-28', '1.1878'],
#  ['2017-11-29', '1.1858'],
#  ['2017-11-30', '1.1898'],
#  ['2017-12-01', '1.1910'],
#  ['2017-12-04', '1.1848'],
#  ['2017-12-05', '1.1820'],
#  ['2017-12-06', '1.1788'],
#  ['2017-12-07', '1.1790'],
#  ['2017-12-08', '1.1761'],
#  ['2017-12-11', '1.1802'],
#  ['2017-12-12', '1.1725'],
#  ['2017-12-13', '1.1762'],
#  ['2017-12-14', '1.1778'],
#  ['2017-12-15', '1.1778'],
#  ['2017-12-18', '1.1804'],
#  ['2017-12-19', '1.1822'],
#  ['2017-12-20', '1.1881'],
#  ['2017-12-21', '1.1872'],
#  ['2017-12-22', '1.1839'],
#  ['2017-12-25', '.'],
#  ['2017-12-26', '1.1867'],
#  ['2017-12-27', '1.1902'],
#  ['2017-12-28', '1.1952'],
#  ['2017-12-29', '1.2022'],
#  ['2018-01-01', '.'],
#  ['2018-01-02', '1.2050'],
#  ['2018-01-03', '1.2030'],
#  ['2018-01-04', '1.2064'],
#  ['2018-01-05', '1.2039'],
#  ['2018-01-08', '1.1973'],
#  ['2018-01-09', '1.1922'],
#  ['2018-01-10', '1.1958'],
#  ['2018-01-11', '1.2035'],
#  ['2018-01-12', '1.2130'],
#  ['2018-01-15', '.'],
#  ['2018-01-16', '1.2244'],
#  ['2018-01-17', '1.2229'],
#  ['2018-01-18', '1.2238'],
#  ['2018-01-19', '1.2238'],
#  ['2018-01-22', '1.2230'],
#  ['2018-01-23', '1.2277'],
#  ['2018-01-24', '1.2390'],
#  ['2018-01-25', '1.2488'],
#  ['2018-01-26', '1.2422'],
#  ['2018-01-29', '1.2352'],
#  ['2018-01-30', '1.2390'],
#  ['2018-01-31', '1.2428'],
#  ['2018-02-01', '1.2482'],
#  ['2018-02-02', '1.2446'],
#  ['2018-02-05', '1.2418'],
#  ['2018-02-06', '1.2381'],
#  ['2018-02-07', '1.2281'],
#  ['2018-02-08', '1.2238'],
#  ['2018-02-09', '1.2226'],
#  ['2018-02-12', '1.2267'],
#  ['2018-02-13', '1.2363'],
#  ['2018-02-14', '1.2396'],
#  ['2018-02-15', '1.2482'],
#  ['2018-02-16', '1.2442'],
#  ['2018-02-19', '.'],
#  ['2018-02-20', '1.2348'],
#  ['2018-02-21', '1.2314'],
#  ['2018-02-22', '1.2326'],
#  ['2018-02-23', '1.2298'],
#  ['2018-02-26', '1.2296'],
#  ['2018-02-27', '1.2239'],
#  ['2018-02-28', '1.2211'],
#  ['2018-03-01', '1.2216'],
#  ['2018-03-02', '1.2314'],
#  ['2018-03-05', '1.233'],
#  ['2018-03-06', '1.2415'],
#  ['2018-03-07', '1.2397'],
#  ['2018-03-08', '1.2314'],
#  ['2018-03-09', '1.2326'],
#  ['2018-03-12', '1.2318'],
#  ['2018-03-13', '1.2398'],
#  ['2018-03-14', '1.2362'],
#  ['2018-03-15', '1.2321'],
#  ['2018-03-16', '1.228'],
#  ['2018-03-19', '1.2329'],
#  ['2018-03-20', '1.2271'],
#  ['2018-03-21', '1.2268'],
#  ['2018-03-22', '1.231'],
#  ['2018-03-23', '1.236'],
#  ['2018-03-26', '1.244'],
#  ['2018-03-27', '1.241'],
#  ['2018-03-28', '1.2351'],
#  ['2018-03-29', '1.2297'],
#  ['2018-03-30', '1.232'],
#  ['2018-04-02', '1.2288'],
#  ['2018-04-03', '1.2261'],
#  ['2018-04-04', '1.2292'],
#  ['2018-04-05', '1.223'],
#  ['2018-04-06', '1.2274'],
#  ['2018-04-09', '1.232'],
#  ['2018-04-10', '1.2338'],
#  ['2018-04-11', '1.2384'],
#  ['2018-04-12', '1.232'],
#  ['2018-04-13', '1.2322'],
#  ['2018-04-16', '1.2373'],
#  ['2018-04-17', '1.2345'],
#  ['2018-04-18', '1.238'],
#  ['2018-04-19', '1.2336'],
#  ['2018-04-20', '1.2282'],
#  ['2018-04-23', '1.2216'],
#  ['2018-04-24', '1.2226'],
#  ['2018-04-25', '1.2178'],
#  ['2018-04-26', '1.2113'],
#  ['2018-04-27', '1.2108'],
#  ['2018-04-30', '1.2074'],
#  ['2018-05-01', '1.2'],
#  ['2018-05-02', '1.1968'],
#  ['2018-05-03', '1.197'],
#  ['2018-05-04', '1.1946'],
#  ['2018-05-07', '1.1927'],
#  ['2018-05-08', '1.1863'],
#  ['2018-05-09', '1.1852'],
#  ['2018-05-10', '1.1896'],
#  ['2018-05-11', '1.1951'],
#  ['2018-05-14', '1.1976'],
#  ['2018-05-15', '1.1864'],
#  ['2018-05-16', '1.1788'],
#  ['2018-05-17', '1.1798'],
#  ['2018-05-18', '1.1775'],
#  ['2018-05-21', '1.1768'],
#  ['2018-05-22', '1.1783'],
#  ['2018-05-23', '1.1693'],
#  ['2018-05-24', '1.1729'],
#  ['2018-05-25', '1.1666'],
#  ['2018-05-28', '.'],
#  ['2018-05-29', '1.1551'],
#  ['2018-05-30', '1.1664'],
#  ['2018-05-31', '1.167'],
#  ['2018-06-01', '1.1679'],
#  ['2018-06-04', '1.1696'],
#  ['2018-06-05', '1.1672'],
#  ['2018-06-06', '1.1778'],
#  ['2018-06-07', '1.1815'],
#  ['2018-06-08', '1.1773'],
#  ['2018-06-11', '1.1802'],
#  ['2018-06-12', '1.1792'],
#  ['2018-06-13', '1.1784'],
#  ['2018-06-14', '1.1634'],
#  ['2018-06-15', '1.1616'],
#  ['2018-06-18', '1.1606'],
#  ['2018-06-19', '1.1577'],
#  ['2018-06-20', '1.1592'],
#  ['2018-06-21', '1.16'],
#  ['2018-06-22', '1.163'],
#  ['2018-06-25', '1.1694'],
#  ['2018-06-26', '1.1675'],
#  ['2018-06-27', '1.1588'],
#  ['2018-06-28', '1.1582'],
#  ['2018-06-29', '1.1677'],
#  ['2018-07-02', '1.1604'],
#  ['2018-07-03', '1.1653'],
#  ['2018-07-04', '.'],
#  ['2018-07-05', '1.1697'],
#  ['2018-07-06', '1.1738'],
#  ['2018-07-09', '1.1744'],
#  ['2018-07-10', '1.1728'],
#  ['2018-07-11', '1.1722'],
#  ['2018-07-12', '1.1692'],
#  ['2018-07-13', '1.1667'],
#  ['2018-07-16', '1.171'],
#  ['2018-07-17', '1.1664'],
#  ['2018-07-18', '1.1645'],
#  ['2018-07-19', '1.1604'],
#  ['2018-07-20', '1.1708'],
#  ['2018-07-23', '1.1702'],
#  ['2018-07-24', '1.1684'],
#  ['2018-07-25', '1.1677'],
#  ['2018-07-26', '1.1654'],
#  ['2018-07-27', '1.166'],
#  ['2018-07-30', '1.1718'],
#  ['2018-07-31', '1.1706'],
#  ['2018-08-01', '1.1666'],
#  ['2018-08-02', '1.1612'],
#  ['2018-08-03', '1.1597'],
#  ['2018-08-06', '1.1564'],
#  ['2018-08-07', '1.1597'],
#  ['2018-08-08', '1.1598'],
#  ['2018-08-09', '1.1566'],
#  ['2018-08-10', '1.1399'],
#  ['2018-08-13', '1.1396'],
#  ['2018-08-14', '1.1351'],
#  ['2018-08-15', '1.1332'],
#  ['2018-08-16', '1.1388'],
#  ['2018-08-17', '1.141'],
#  ['2018-08-20', '1.1438'],
#  ['2018-08-21', '1.1534'],
#  ['2018-08-22', '1.1595'],
#  ['2018-08-23', '1.1567'],
#  ['2018-08-24', '1.1625'],
#  ['2018-08-27', '1.1676'],
#  ['2018-08-28', '1.172'],
#  ['2018-08-29', '1.1699'],
#  ['2018-08-30', '1.1646'],
#  ['2018-08-31', '1.1596'],
#  ['2018-09-03', '.'],
#  ['2018-09-04', '1.1566'],
#  ['2018-09-05', '1.162'],
#  ['2018-09-06', '1.1624'],
#  ['2018-09-07', '1.1572'],
#  ['2018-09-10', '1.1604'],
#  ['2018-09-11', '1.1591'],
#  ['2018-09-12', '1.1626'],
#  ['2018-09-13', '1.1672'],
#  ['2018-09-14', '1.1656'],
#  ['2018-09-17', '1.1687'],
#  ['2018-09-18', '1.1693'],
#  ['2018-09-19', '1.1685'],
#  ['2018-09-20', '1.1744'],
#  ['2018-09-21', '1.1739'],
#  ['2018-09-24', '1.1773'],
#  ['2018-09-25', '1.177'],
#  ['2018-09-26', '1.1758'],
#  ['2018-09-27', '1.167'],
#  ['2018-09-28', '1.1622'],
#  ['2018-10-01', '1.1567'],
#  ['2018-10-02', '1.156'],
#  ['2018-10-03', '1.1525'],
#  ['2018-10-04', '1.1508'],
#  ['2018-10-05', '1.1502'],
#  ['2018-10-08', '.'],
#  ['2018-10-09', '1.1482'],
#  ['2018-10-10', '1.1541'],
#  ['2018-10-11', '1.1565'],
#  ['2018-10-12', '1.1559'],
#  ['2018-10-15', '1.1594'],
#  ['2018-10-16', '1.1593'],
#  ['2018-10-17', '1.154'],
#  ['2018-10-18', '1.1494'],
#  ['2018-10-19', '1.1513'],
#  ['2018-10-22', '1.1467'],
#  ['2018-10-23', '1.148'],
#  ['2018-10-24', '1.1389'],
#  ['2018-10-25', '1.1374'],
#  ['2018-10-26', '1.1388'],
#  ['2018-10-29', '1.139'],
#  ['2018-10-30', '1.1364'],
#  ['2018-10-31', '1.1332'],
#  ['2018-11-01', '1.1396'],
#  ['2018-11-02', '1.1378'],
#  ['2018-11-05', '1.1394'],
#  ['2018-11-06', '1.1412'],
#  ['2018-11-07', '1.1459'],
#  ['2018-11-08', '1.1416'],
#  ['2018-11-09', '1.1325'],
#  ['2018-11-12', '.'],
#  ['2018-11-13', '1.1288'],
#  ['2018-11-14', '1.1312'],
#  ['2018-11-15', '1.1324'],
#  ['2018-11-16', '1.1402'],
#  ['2018-11-19', '1.1448'],
#  ['2018-11-20', '1.1391'],
#  ['2018-11-21', '1.1393'],
#  ['2018-11-22', '.'],
#  ['2018-11-23', '1.1332'],
#  ['2018-11-26', '1.1336'],
#  ['2018-11-27', '1.1281'],
#  ['2018-11-28', '1.1286'],
#  ['2018-11-29', '1.1382'],
#  ['2018-11-30', '1.1323'],
#  ['2018-12-03', '1.1356'],
#  ['2018-12-04', '1.1345'],
#  ['2018-12-05', '.'],
#  ['2018-12-06', '1.1374'],
#  ['2018-12-07', '1.139'],
#  ['2018-12-10', '1.1368'],
#  ['2018-12-11', '1.1314'],
#  ['2018-12-12', '1.1362'],
#  ['2018-12-13', '1.1358'],
#  ['2018-12-14', '1.13'],
#  ['2018-12-17', '1.1339'],
#  ['2018-12-18', '1.1364'],
#  ['2018-12-19', '1.1422'],
#  ['2018-12-20', '1.1432'],
#  ['2018-12-21', '1.1402'],
#  ['2018-12-24', '.'],
#  ['2018-12-25', '.'],
#  ['2018-12-26', '1.1408'],
#  ['2018-12-27', '1.1412'],
#  ['2018-12-28', '1.1445'],
#  ['2018-12-31', '1.1456'],
#  ['2019-01-01', '.'],
#  ['2019-01-02', '1.1357'],
#  ['2019-01-03', '1.1399'],
#  ['2019-01-04', '1.141'],
#  ['2019-01-07', '1.1468'],
#  ['2019-01-08', '1.1444'],
#  ['2019-01-09', '1.1524'],
#  ['2019-01-10', '1.1517'],
#  ['2019-01-11', '1.1479'],
#  ['2019-01-14', '.'],
#  ['2019-01-15', '1.1392'],
#  ['2019-01-16', '1.1408'],
#  ['2019-01-17', '1.1386'],
#  ['2019-01-18', '1.1362'],
#  ['2019-01-21', '.'],
#  ['2019-01-22', '1.1359'],
#  ['2019-01-23', '1.139'],
#  ['2019-01-24', '1.1322'],
#  ['2019-01-25', '1.1407'],
#  ['2019-01-28', '1.1438'],
#  ['2019-01-29', '1.1424'],
#  ['2019-01-30', '1.1418'],
#  ['2019-01-31', '1.1454'],
#  ...]

# %% [markdown]
# This is a good start, but we still want to parse the date and values into `date` and `Decimal` objects:

# %%
class Forex:
    def __init__(self, file_name):
        with open(file_name) as f:
            reader = csv.reader(f)
            
            self.headers = next(reader)
            self.data = [
                (datetime.strptime(date, '%Y-%m-%d').date(), Decimal(value))
                for date, value in reader
                if value != '.'
            ]

# %%
forex = Forex(file_name)

# %%
forex.data
# Out:
# [(datetime.date(2015, 4, 3), Decimal('1.0990')),
#  (datetime.date(2015, 4, 6), Decimal('1.1008')),
#  (datetime.date(2015, 4, 7), Decimal('1.0850')),
#  (datetime.date(2015, 4, 8), Decimal('1.0818')),
#  (datetime.date(2015, 4, 9), Decimal('1.0671')),
#  (datetime.date(2015, 4, 10), Decimal('1.0598')),
#  (datetime.date(2015, 4, 13), Decimal('1.0582')),
#  (datetime.date(2015, 4, 14), Decimal('1.0672')),
#  (datetime.date(2015, 4, 15), Decimal('1.0596')),
#  (datetime.date(2015, 4, 16), Decimal('1.0742')),
#  (datetime.date(2015, 4, 17), Decimal('1.0780')),
#  (datetime.date(2015, 4, 20), Decimal('1.0763')),
#  (datetime.date(2015, 4, 21), Decimal('1.0758')),
#  (datetime.date(2015, 4, 22), Decimal('1.0729')),
#  (datetime.date(2015, 4, 23), Decimal('1.0803')),
#  (datetime.date(2015, 4, 24), Decimal('1.0876')),
#  (datetime.date(2015, 4, 27), Decimal('1.0892')),
#  (datetime.date(2015, 4, 28), Decimal('1.0979')),
#  (datetime.date(2015, 4, 29), Decimal('1.1174')),
#  (datetime.date(2015, 4, 30), Decimal('1.1162')),
#  (datetime.date(2015, 5, 1), Decimal('1.1194')),
#  (datetime.date(2015, 5, 4), Decimal('1.1145')),
#  (datetime.date(2015, 5, 5), Decimal('1.1174')),
#  (datetime.date(2015, 5, 6), Decimal('1.1345')),
#  (datetime.date(2015, 5, 7), Decimal('1.1283')),
#  (datetime.date(2015, 5, 8), Decimal('1.1241')),
#  (datetime.date(2015, 5, 11), Decimal('1.1142')),
#  (datetime.date(2015, 5, 12), Decimal('1.1240')),
#  (datetime.date(2015, 5, 13), Decimal('1.1372')),
#  (datetime.date(2015, 5, 14), Decimal('1.1368')),
#  (datetime.date(2015, 5, 15), Decimal('1.1428')),
#  (datetime.date(2015, 5, 18), Decimal('1.1354')),
#  (datetime.date(2015, 5, 19), Decimal('1.1151')),
#  (datetime.date(2015, 5, 20), Decimal('1.1079')),
#  (datetime.date(2015, 5, 21), Decimal('1.1126')),
#  (datetime.date(2015, 5, 22), Decimal('1.1033')),
#  (datetime.date(2015, 5, 26), Decimal('1.0876')),
#  (datetime.date(2015, 5, 27), Decimal('1.0888')),
#  (datetime.date(2015, 5, 28), Decimal('1.0914')),
#  (datetime.date(2015, 5, 29), Decimal('1.0994')),
#  (datetime.date(2015, 6, 1), Decimal('1.0913')),
#  (datetime.date(2015, 6, 2), Decimal('1.1130')),
#  (datetime.date(2015, 6, 3), Decimal('1.1285')),
#  (datetime.date(2015, 6, 4), Decimal('1.1271')),
#  (datetime.date(2015, 6, 5), Decimal('1.1108')),
#  (datetime.date(2015, 6, 8), Decimal('1.1232')),
#  (datetime.date(2015, 6, 9), Decimal('1.1284')),
#  (datetime.date(2015, 6, 10), Decimal('1.1307')),
#  (datetime.date(2015, 6, 11), Decimal('1.1236')),
#  (datetime.date(2015, 6, 12), Decimal('1.1278')),
#  (datetime.date(2015, 6, 15), Decimal('1.1266')),
#  (datetime.date(2015, 6, 16), Decimal('1.1238')),
#  (datetime.date(2015, 6, 17), Decimal('1.1244')),
#  (datetime.date(2015, 6, 18), Decimal('1.1404')),
#  (datetime.date(2015, 6, 19), Decimal('1.1335')),
#  (datetime.date(2015, 6, 22), Decimal('1.1378')),
#  (datetime.date(2015, 6, 23), Decimal('1.1190')),
#  (datetime.date(2015, 6, 24), Decimal('1.1178')),
#  (datetime.date(2015, 6, 25), Decimal('1.1196')),
#  (datetime.date(2015, 6, 26), Decimal('1.1156')),
#  (datetime.date(2015, 6, 29), Decimal('1.1180')),
#  (datetime.date(2015, 6, 30), Decimal('1.1154')),
#  (datetime.date(2015, 7, 1), Decimal('1.1084')),
#  (datetime.date(2015, 7, 2), Decimal('1.1090')),
#  (datetime.date(2015, 7, 6), Decimal('1.1076')),
#  (datetime.date(2015, 7, 7), Decimal('1.0952')),
#  (datetime.date(2015, 7, 8), Decimal('1.1072')),
#  (datetime.date(2015, 7, 9), Decimal('1.1025')),
#  (datetime.date(2015, 7, 10), Decimal('1.1150')),
#  (datetime.date(2015, 7, 13), Decimal('1.1020')),
#  (datetime.date(2015, 7, 14), Decimal('1.1015')),
#  (datetime.date(2015, 7, 15), Decimal('1.0965')),
#  (datetime.date(2015, 7, 16), Decimal('1.0898')),
#  (datetime.date(2015, 7, 17), Decimal('1.0848')),
#  (datetime.date(2015, 7, 20), Decimal('1.0850')),
#  (datetime.date(2015, 7, 21), Decimal('1.0927')),
#  (datetime.date(2015, 7, 22), Decimal('1.0884')),
#  (datetime.date(2015, 7, 23), Decimal('1.0976')),
#  (datetime.date(2015, 7, 24), Decimal('1.0976')),
#  (datetime.date(2015, 7, 27), Decimal('1.1112')),
#  (datetime.date(2015, 7, 28), Decimal('1.1055')),
#  (datetime.date(2015, 7, 29), Decimal('1.1026')),
#  (datetime.date(2015, 7, 30), Decimal('1.0914')),
#  (datetime.date(2015, 7, 31), Decimal('1.1028')),
#  (datetime.date(2015, 8, 3), Decimal('1.0962')),
#  (datetime.date(2015, 8, 4), Decimal('1.0953')),
#  (datetime.date(2015, 8, 5), Decimal('1.0868')),
#  (datetime.date(2015, 8, 6), Decimal('1.0922')),
#  (datetime.date(2015, 8, 7), Decimal('1.0958')),
#  (datetime.date(2015, 8, 10), Decimal('1.0994')),
#  (datetime.date(2015, 8, 11), Decimal('1.1042')),
#  (datetime.date(2015, 8, 12), Decimal('1.1198')),
#  (datetime.date(2015, 8, 13), Decimal('1.1144')),
#  (datetime.date(2015, 8, 14), Decimal('1.1110')),
#  (datetime.date(2015, 8, 17), Decimal('1.1078')),
#  (datetime.date(2015, 8, 18), Decimal('1.1028')),
#  (datetime.date(2015, 8, 19), Decimal('1.1061')),
#  (datetime.date(2015, 8, 20), Decimal('1.1200')),
#  (datetime.date(2015, 8, 21), Decimal('1.1356')),
#  (datetime.date(2015, 8, 24), Decimal('1.1580')),
#  (datetime.date(2015, 8, 25), Decimal('1.1410')),
#  (datetime.date(2015, 8, 26), Decimal('1.1390')),
#  (datetime.date(2015, 8, 27), Decimal('1.1239')),
#  (datetime.date(2015, 8, 28), Decimal('1.1172')),
#  (datetime.date(2015, 8, 31), Decimal('1.1194')),
#  (datetime.date(2015, 9, 1), Decimal('1.1263')),
#  (datetime.date(2015, 9, 2), Decimal('1.1242')),
#  (datetime.date(2015, 9, 3), Decimal('1.1104')),
#  (datetime.date(2015, 9, 4), Decimal('1.1117')),
#  (datetime.date(2015, 9, 8), Decimal('1.1182')),
#  (datetime.date(2015, 9, 9), Decimal('1.1165')),
#  (datetime.date(2015, 9, 10), Decimal('1.1262')),
#  (datetime.date(2015, 9, 11), Decimal('1.1338')),
#  (datetime.date(2015, 9, 14), Decimal('1.1307')),
#  (datetime.date(2015, 9, 15), Decimal('1.1260')),
#  (datetime.date(2015, 9, 16), Decimal('1.1304')),
#  (datetime.date(2015, 9, 17), Decimal('1.1312')),
#  (datetime.date(2015, 9, 18), Decimal('1.1358')),
#  (datetime.date(2015, 9, 21), Decimal('1.1204')),
#  (datetime.date(2015, 9, 22), Decimal('1.1133')),
#  (datetime.date(2015, 9, 23), Decimal('1.1160')),
#  (datetime.date(2015, 9, 24), Decimal('1.1252')),
#  (datetime.date(2015, 9, 25), Decimal('1.1192')),
#  (datetime.date(2015, 9, 28), Decimal('1.1236')),
#  (datetime.date(2015, 9, 29), Decimal('1.1246')),
#  (datetime.date(2015, 9, 30), Decimal('1.1162')),
#  (datetime.date(2015, 10, 1), Decimal('1.1200')),
#  (datetime.date(2015, 10, 2), Decimal('1.1276')),
#  (datetime.date(2015, 10, 5), Decimal('1.1200')),
#  (datetime.date(2015, 10, 6), Decimal('1.1266')),
#  (datetime.date(2015, 10, 7), Decimal('1.1249')),
#  (datetime.date(2015, 10, 8), Decimal('1.1282')),
#  (datetime.date(2015, 10, 9), Decimal('1.1363')),
#  (datetime.date(2015, 10, 13), Decimal('1.1382')),
#  (datetime.date(2015, 10, 14), Decimal('1.1437')),
#  (datetime.date(2015, 10, 15), Decimal('1.1418')),
#  (datetime.date(2015, 10, 16), Decimal('1.1360')),
#  (datetime.date(2015, 10, 19), Decimal('1.1320')),
#  (datetime.date(2015, 10, 20), Decimal('1.1359')),
#  (datetime.date(2015, 10, 21), Decimal('1.1345')),
#  (datetime.date(2015, 10, 22), Decimal('1.1140')),
#  (datetime.date(2015, 10, 23), Decimal('1.1016')),
#  (datetime.date(2015, 10, 26), Decimal('1.1051')),
#  (datetime.date(2015, 10, 27), Decimal('1.1052')),
#  (datetime.date(2015, 10, 28), Decimal('1.1066')),
#  (datetime.date(2015, 10, 29), Decimal('1.0963')),
#  (datetime.date(2015, 10, 30), Decimal('1.1042')),
#  (datetime.date(2015, 11, 2), Decimal('1.1026')),
#  (datetime.date(2015, 11, 3), Decimal('1.0946')),
#  (datetime.date(2015, 11, 4), Decimal('1.0861')),
#  (datetime.date(2015, 11, 5), Decimal('1.0869')),
#  (datetime.date(2015, 11, 6), Decimal('1.0746')),
#  (datetime.date(2015, 11, 9), Decimal('1.0767')),
#  (datetime.date(2015, 11, 10), Decimal('1.0686')),
#  (datetime.date(2015, 11, 12), Decimal('1.0768')),
#  (datetime.date(2015, 11, 13), Decimal('1.0722')),
#  (datetime.date(2015, 11, 16), Decimal('1.0708')),
#  (datetime.date(2015, 11, 17), Decimal('1.0634')),
#  (datetime.date(2015, 11, 18), Decimal('1.0638')),
#  (datetime.date(2015, 11, 19), Decimal('1.0746')),
#  (datetime.date(2015, 11, 20), Decimal('1.0660')),
#  (datetime.date(2015, 11, 23), Decimal('1.0602')),
#  (datetime.date(2015, 11, 24), Decimal('1.0652')),
#  (datetime.date(2015, 11, 25), Decimal('1.0616')),
#  (datetime.date(2015, 11, 27), Decimal('1.0596')),
#  (datetime.date(2015, 11, 30), Decimal('1.0562')),
#  (datetime.date(2015, 12, 1), Decimal('1.0620')),
#  (datetime.date(2015, 12, 2), Decimal('1.0573')),
#  (datetime.date(2015, 12, 3), Decimal('1.0902')),
#  (datetime.date(2015, 12, 4), Decimal('1.0884')),
#  (datetime.date(2015, 12, 7), Decimal('1.0840')),
#  (datetime.date(2015, 12, 8), Decimal('1.0876')),
#  (datetime.date(2015, 12, 9), Decimal('1.0984')),
#  (datetime.date(2015, 12, 10), Decimal('1.0948')),
#  (datetime.date(2015, 12, 11), Decimal('1.1002')),
#  (datetime.date(2015, 12, 14), Decimal('1.1025')),
#  (datetime.date(2015, 12, 15), Decimal('1.0911')),
#  (datetime.date(2015, 12, 16), Decimal('1.0937')),
#  (datetime.date(2015, 12, 17), Decimal('1.0804')),
#  (datetime.date(2015, 12, 18), Decimal('1.0847')),
#  (datetime.date(2015, 12, 21), Decimal('1.0920')),
#  (datetime.date(2015, 12, 22), Decimal('1.0978')),
#  (datetime.date(2015, 12, 23), Decimal('1.0875')),
#  (datetime.date(2015, 12, 24), Decimal('1.0955')),
#  (datetime.date(2015, 12, 28), Decimal('1.0983')),
#  (datetime.date(2015, 12, 29), Decimal('1.0916')),
#  (datetime.date(2015, 12, 30), Decimal('1.0912')),
#  (datetime.date(2015, 12, 31), Decimal('1.0859')),
#  (datetime.date(2016, 1, 4), Decimal('1.0803')),
#  (datetime.date(2016, 1, 5), Decimal('1.0743')),
#  (datetime.date(2016, 1, 6), Decimal('1.0762')),
#  (datetime.date(2016, 1, 7), Decimal('1.0860')),
#  (datetime.date(2016, 1, 8), Decimal('1.0885')),
#  (datetime.date(2016, 1, 11), Decimal('1.0878')),
#  (datetime.date(2016, 1, 12), Decimal('1.0837')),
#  (datetime.date(2016, 1, 13), Decimal('1.0862')),
#  (datetime.date(2016, 1, 14), Decimal('1.0862')),
#  (datetime.date(2016, 1, 15), Decimal('1.0964')),
#  (datetime.date(2016, 1, 19), Decimal('1.0906')),
#  (datetime.date(2016, 1, 20), Decimal('1.0908')),
#  (datetime.date(2016, 1, 21), Decimal('1.0833')),
#  (datetime.date(2016, 1, 22), Decimal('1.0814')),
#  (datetime.date(2016, 1, 25), Decimal('1.0832')),
#  (datetime.date(2016, 1, 26), Decimal('1.0846')),
#  (datetime.date(2016, 1, 27), Decimal('1.0867')),
#  (datetime.date(2016, 1, 28), Decimal('1.0952')),
#  (datetime.date(2016, 1, 29), Decimal('1.0832')),
#  (datetime.date(2016, 2, 1), Decimal('1.0888')),
#  (datetime.date(2016, 2, 2), Decimal('1.0908')),
#  (datetime.date(2016, 2, 3), Decimal('1.1051')),
#  (datetime.date(2016, 2, 4), Decimal('1.1199')),
#  (datetime.date(2016, 2, 5), Decimal('1.1131')),
#  (datetime.date(2016, 2, 8), Decimal('1.1170')),
#  (datetime.date(2016, 2, 9), Decimal('1.1300')),
#  (datetime.date(2016, 2, 10), Decimal('1.1222')),
#  (datetime.date(2016, 2, 11), Decimal('1.1362')),
#  (datetime.date(2016, 2, 12), Decimal('1.1235')),
#  (datetime.date(2016, 2, 16), Decimal('1.1140')),
#  (datetime.date(2016, 2, 17), Decimal('1.1140')),
#  (datetime.date(2016, 2, 18), Decimal('1.1092')),
#  (datetime.date(2016, 2, 19), Decimal('1.1127')),
#  (datetime.date(2016, 2, 22), Decimal('1.1018')),
#  (datetime.date(2016, 2, 23), Decimal('1.1016')),
#  (datetime.date(2016, 2, 24), Decimal('1.1021')),
#  (datetime.date(2016, 2, 25), Decimal('1.1026')),
#  (datetime.date(2016, 2, 26), Decimal('1.0932')),
#  (datetime.date(2016, 2, 29), Decimal('1.0868')),
#  (datetime.date(2016, 3, 1), Decimal('1.0847')),
#  (datetime.date(2016, 3, 2), Decimal('1.0845')),
#  (datetime.date(2016, 3, 3), Decimal('1.0948')),
#  (datetime.date(2016, 3, 4), Decimal('1.1010')),
#  (datetime.date(2016, 3, 7), Decimal('1.1004')),
#  (datetime.date(2016, 3, 8), Decimal('1.1028')),
#  (datetime.date(2016, 3, 9), Decimal('1.1022')),
#  (datetime.date(2016, 3, 10), Decimal('1.1162')),
#  (datetime.date(2016, 5, 24), Decimal('1.1145')),
#  (datetime.date(2016, 5, 25), Decimal('1.1154')),
#  (datetime.date(2016, 5, 26), Decimal('1.1184')),
#  (datetime.date(2016, 5, 27), Decimal('1.1140')),
#  (datetime.date(2016, 5, 31), Decimal('1.1135')),
#  (datetime.date(2016, 6, 1), Decimal('1.1165')),
#  (datetime.date(2016, 6, 2), Decimal('1.1157')),
#  (datetime.date(2016, 6, 3), Decimal('1.1330')),
#  (datetime.date(2016, 6, 6), Decimal('1.1354')),
#  (datetime.date(2016, 6, 7), Decimal('1.1350')),
#  (datetime.date(2016, 6, 8), Decimal('1.1400')),
#  (datetime.date(2016, 6, 9), Decimal('1.1329')),
#  (datetime.date(2016, 6, 10), Decimal('1.1281')),
#  (datetime.date(2016, 6, 13), Decimal('1.1282')),
#  (datetime.date(2016, 6, 14), Decimal('1.1206')),
#  (datetime.date(2016, 6, 15), Decimal('1.1239')),
#  (datetime.date(2016, 6, 16), Decimal('1.1158')),
#  (datetime.date(2016, 6, 17), Decimal('1.1256')),
#  (datetime.date(2016, 6, 20), Decimal('1.1318')),
#  (datetime.date(2016, 6, 21), Decimal('1.1262')),
#  (datetime.date(2016, 6, 22), Decimal('1.1286')),
#  (datetime.date(2016, 6, 23), Decimal('1.1373')),
#  (datetime.date(2016, 6, 24), Decimal('1.1126')),
#  (datetime.date(2016, 6, 27), Decimal('1.1024')),
#  (datetime.date(2016, 6, 28), Decimal('1.1054')),
#  (datetime.date(2016, 6, 29), Decimal('1.1117')),
#  (datetime.date(2016, 6, 30), Decimal('1.1032')),
#  (datetime.date(2016, 7, 1), Decimal('1.1145')),
#  (datetime.date(2016, 7, 5), Decimal('1.1080')),
#  (datetime.date(2016, 7, 6), Decimal('1.1077')),
#  (datetime.date(2016, 7, 7), Decimal('1.1065')),
#  (datetime.date(2016, 7, 8), Decimal('1.1038')),
#  (datetime.date(2016, 7, 11), Decimal('1.1045')),
#  (datetime.date(2016, 7, 12), Decimal('1.1074')),
#  (datetime.date(2016, 7, 13), Decimal('1.1112')),
#  (datetime.date(2016, 7, 14), Decimal('1.1109')),
#  (datetime.date(2016, 7, 15), Decimal('1.1059')),
#  (datetime.date(2016, 7, 18), Decimal('1.1076')),
#  (datetime.date(2016, 7, 19), Decimal('1.1014')),
#  (datetime.date(2016, 7, 20), Decimal('1.1007')),
#  (datetime.date(2016, 7, 21), Decimal('1.1016')),
#  (datetime.date(2016, 7, 22), Decimal('1.0968')),
#  (datetime.date(2016, 7, 25), Decimal('1.0980')),
#  (datetime.date(2016, 7, 26), Decimal('1.0984')),
#  (datetime.date(2016, 7, 27), Decimal('1.0988')),
#  (datetime.date(2016, 7, 28), Decimal('1.1094')),
#  (datetime.date(2016, 7, 29), Decimal('1.1168')),
#  (datetime.date(2016, 8, 1), Decimal('1.1176')),
#  (datetime.date(2016, 8, 2), Decimal('1.1225')),
#  (datetime.date(2016, 8, 3), Decimal('1.1170')),
#  (datetime.date(2016, 8, 4), Decimal('1.1134')),
#  (datetime.date(2016, 8, 5), Decimal('1.1080')),
#  (datetime.date(2017, 1, 6), Decimal('1.0560')),
#  (datetime.date(2017, 1, 9), Decimal('1.0576')),
#  (datetime.date(2017, 1, 10), Decimal('1.0572')),
#  (datetime.date(2017, 1, 11), Decimal('1.0501')),
#  (datetime.date(2017, 1, 12), Decimal('1.0666')),
#  (datetime.date(2017, 1, 13), Decimal('1.0625')),
#  (datetime.date(2017, 1, 17), Decimal('1.0695')),
#  (datetime.date(2017, 1, 18), Decimal('1.0682')),
#  (datetime.date(2017, 1, 19), Decimal('1.0630')),
#  (datetime.date(2017, 1, 23), Decimal('1.0740')),
#  (datetime.date(2017, 1, 24), Decimal('1.0749')),
#  (datetime.date(2017, 1, 25), Decimal('1.0743')),
#  (datetime.date(2017, 1, 26), Decimal('1.0670')),
#  (datetime.date(2017, 1, 27), Decimal('1.0690')),
#  (datetime.date(2017, 1, 30), Decimal('1.0681')),
#  (datetime.date(2017, 1, 31), Decimal('1.0794')),
#  (datetime.date(2017, 2, 1), Decimal('1.0758')),
#  (datetime.date(2017, 2, 2), Decimal('1.0802')),
#  (datetime.date(2017, 2, 3), Decimal('1.0792')),
#  (datetime.date(2017, 2, 6), Decimal('1.0731')),
#  (datetime.date(2017, 2, 7), Decimal('1.0690')),
#  (datetime.date(2017, 2, 8), Decimal('1.0708')),
#  (datetime.date(2017, 2, 9), Decimal('1.0658')),
#  (datetime.date(2017, 2, 10), Decimal('1.0650')),
#  (datetime.date(2017, 2, 13), Decimal('1.0603')),
#  (datetime.date(2017, 2, 14), Decimal('1.0577')),
#  (datetime.date(2017, 2, 15), Decimal('1.0597')),
#  (datetime.date(2017, 2, 16), Decimal('1.0660')),
#  (datetime.date(2017, 2, 17), Decimal('1.0614')),
#  (datetime.date(2017, 2, 21), Decimal('1.0551')),
#  (datetime.date(2017, 2, 22), Decimal('1.0555')),
#  (datetime.date(2017, 2, 23), Decimal('1.0586')),
#  (datetime.date(2017, 2, 24), Decimal('1.0580')),
#  (datetime.date(2017, 2, 27), Decimal('1.0624')),
#  (datetime.date(2017, 2, 28), Decimal('1.0618')),
#  (datetime.date(2017, 3, 1), Decimal('1.0564')),
#  (datetime.date(2017, 3, 2), Decimal('1.0514')),
#  (datetime.date(2017, 3, 3), Decimal('1.0552')),
#  (datetime.date(2017, 3, 6), Decimal('1.0586')),
#  (datetime.date(2017, 3, 7), Decimal('1.0582')),
#  (datetime.date(2017, 3, 8), Decimal('1.0547')),
#  (datetime.date(2017, 3, 9), Decimal('1.0586')),
#  (datetime.date(2017, 3, 10), Decimal('1.0667')),
#  (datetime.date(2017, 3, 13), Decimal('1.0670')),
#  (datetime.date(2017, 3, 14), Decimal('1.0645')),
#  (datetime.date(2017, 3, 15), Decimal('1.0630')),
#  (datetime.date(2017, 3, 16), Decimal('1.0738')),
#  (datetime.date(2017, 3, 17), Decimal('1.0742')),
#  (datetime.date(2017, 3, 20), Decimal('1.0754')),
#  (datetime.date(2017, 3, 21), Decimal('1.0810')),
#  (datetime.date(2017, 3, 22), Decimal('1.0800')),
#  (datetime.date(2017, 3, 23), Decimal('1.0787')),
#  (datetime.date(2017, 3, 24), Decimal('1.0806')),
#  (datetime.date(2017, 3, 27), Decimal('1.0882')),
#  (datetime.date(2017, 3, 28), Decimal('1.0852')),
#  (datetime.date(2017, 3, 29), Decimal('1.0756')),
#  (datetime.date(2017, 3, 30), Decimal('1.0726')),
#  (datetime.date(2017, 3, 31), Decimal('1.0698')),
#  (datetime.date(2017, 4, 3), Decimal('1.0655')),
#  (datetime.date(2017, 4, 4), Decimal('1.0664')),
#  (datetime.date(2017, 4, 5), Decimal('1.0661')),
#  (datetime.date(2017, 4, 6), Decimal('1.0651')),
#  (datetime.date(2017, 4, 7), Decimal('1.0616')),
#  (datetime.date(2017, 4, 10), Decimal('1.0606')),
#  (datetime.date(2017, 4, 11), Decimal('1.0614')),
#  (datetime.date(2017, 4, 12), Decimal('1.0611')),
#  (datetime.date(2017, 4, 13), Decimal('1.0630')),
#  (datetime.date(2017, 4, 14), Decimal('1.0625')),
#  (datetime.date(2017, 4, 17), Decimal('1.0660')),
#  (datetime.date(2017, 4, 18), Decimal('1.0706')),
#  (datetime.date(2017, 4, 19), Decimal('1.0707')),
#  (datetime.date(2017, 4, 20), Decimal('1.0758')),
#  (datetime.date(2017, 4, 21), Decimal('1.0694')),
#  (datetime.date(2017, 4, 24), Decimal('1.0846')),
#  (datetime.date(2017, 4, 25), Decimal('1.0941')),
#  (datetime.date(2017, 4, 26), Decimal('1.0872')),
#  (datetime.date(2017, 4, 27), Decimal('1.0864')),
#  (datetime.date(2017, 4, 28), Decimal('1.0895')),
#  (datetime.date(2017, 5, 1), Decimal('1.0912')),
#  (datetime.date(2017, 5, 2), Decimal('1.0910')),
#  (datetime.date(2017, 5, 3), Decimal('1.0920')),
#  (datetime.date(2017, 5, 4), Decimal('1.0967')),
#  (datetime.date(2017, 5, 5), Decimal('1.0996')),
#  (datetime.date(2017, 5, 8), Decimal('1.0928')),
#  (datetime.date(2017, 5, 9), Decimal('1.0875')),
#  (datetime.date(2017, 5, 10), Decimal('1.0873')),
#  (datetime.date(2017, 5, 11), Decimal('1.0869')),
#  (datetime.date(2017, 5, 12), Decimal('1.0926')),
#  (datetime.date(2017, 5, 15), Decimal('1.0979')),
#  (datetime.date(2017, 5, 16), Decimal('1.1072')),
#  (datetime.date(2017, 5, 17), Decimal('1.1134')),
#  (datetime.date(2017, 5, 18), Decimal('1.1130')),
#  (datetime.date(2017, 5, 19), Decimal('1.1190')),
#  (datetime.date(2017, 5, 22), Decimal('1.1236')),
#  (datetime.date(2017, 5, 23), Decimal('1.1198')),
#  (datetime.date(2017, 5, 24), Decimal('1.1175')),
#  (datetime.date(2017, 5, 25), Decimal('1.1218')),
#  (datetime.date(2017, 5, 26), Decimal('1.1170')),
#  (datetime.date(2017, 5, 30), Decimal('1.1183')),
#  (datetime.date(2017, 5, 31), Decimal('1.1236')),
#  (datetime.date(2017, 6, 1), Decimal('1.1214')),
#  (datetime.date(2017, 6, 2), Decimal('1.1270')),
#  (datetime.date(2017, 6, 5), Decimal('1.1250')),
#  (datetime.date(2017, 8, 18), Decimal('1.1748')),
#  (datetime.date(2017, 8, 21), Decimal('1.1814')),
#  (datetime.date(2017, 8, 22), Decimal('1.1762')),
#  (datetime.date(2017, 8, 23), Decimal('1.1802')),
#  (datetime.date(2017, 8, 24), Decimal('1.1801')),
#  (datetime.date(2017, 8, 25), Decimal('1.1874')),
#  (datetime.date(2017, 8, 28), Decimal('1.1973')),
#  (datetime.date(2017, 8, 29), Decimal('1.2025')),
#  (datetime.date(2017, 8, 30), Decimal('1.1927')),
#  (datetime.date(2017, 8, 31), Decimal('1.1894')),
#  (datetime.date(2017, 9, 1), Decimal('1.1878')),
#  (datetime.date(2017, 9, 5), Decimal('1.1911')),
#  (datetime.date(2017, 9, 6), Decimal('1.1943')),
#  (datetime.date(2017, 9, 7), Decimal('1.2028')),
#  (datetime.date(2017, 9, 8), Decimal('1.2041')),
#  (datetime.date(2017, 9, 11), Decimal('1.1964')),
#  (datetime.date(2017, 9, 12), Decimal('1.1968')),
#  (datetime.date(2017, 9, 13), Decimal('1.1898')),
#  (datetime.date(2017, 9, 14), Decimal('1.1886')),
#  (datetime.date(2017, 9, 15), Decimal('1.1959')),
#  (datetime.date(2017, 9, 18), Decimal('1.1938')),
#  (datetime.date(2017, 9, 19), Decimal('1.1980')),
#  (datetime.date(2017, 9, 20), Decimal('1.1998')),
#  (datetime.date(2017, 9, 21), Decimal('1.1946')),
#  (datetime.date(2017, 9, 22), Decimal('1.1969')),
#  (datetime.date(2017, 9, 25), Decimal('1.1852')),
#  (datetime.date(2017, 9, 26), Decimal('1.1772')),
#  (datetime.date(2017, 9, 27), Decimal('1.1747')),
#  (datetime.date(2017, 9, 28), Decimal('1.1776')),
#  (datetime.date(2017, 9, 29), Decimal('1.1813')),
#  (datetime.date(2017, 10, 2), Decimal('1.1745')),
#  (datetime.date(2017, 10, 3), Decimal('1.1759')),
#  (datetime.date(2017, 10, 4), Decimal('1.1760')),
#  (datetime.date(2017, 10, 5), Decimal('1.1706')),
#  (datetime.date(2017, 10, 6), Decimal('1.1732')),
#  (datetime.date(2017, 10, 10), Decimal('1.1804')),
#  (datetime.date(2017, 10, 11), Decimal('1.1847')),
#  (datetime.date(2017, 10, 12), Decimal('1.1840')),
#  (datetime.date(2017, 10, 13), Decimal('1.1837')),
#  (datetime.date(2017, 10, 16), Decimal('1.1810')),
#  (datetime.date(2017, 10, 17), Decimal('1.1754')),
#  (datetime.date(2017, 10, 18), Decimal('1.1775')),
#  (datetime.date(2017, 10, 19), Decimal('1.1842')),
#  (datetime.date(2017, 10, 20), Decimal('1.1770')),
#  (datetime.date(2017, 10, 23), Decimal('1.1762')),
#  (datetime.date(2017, 10, 24), Decimal('1.1766')),
#  (datetime.date(2017, 10, 25), Decimal('1.1802')),
#  (datetime.date(2017, 10, 26), Decimal('1.1700')),
#  (datetime.date(2017, 10, 27), Decimal('1.1580')),
#  (datetime.date(2017, 10, 30), Decimal('1.1626')),
#  (datetime.date(2017, 10, 31), Decimal('1.1648')),
#  (datetime.date(2017, 11, 1), Decimal('1.1618')),
#  (datetime.date(2019, 2, 6), Decimal('1.138')),
#  (datetime.date(2019, 2, 7), Decimal('1.1357')),
#  (datetime.date(2019, 2, 8), Decimal('1.1326')),
#  (datetime.date(2019, 2, 11), Decimal('1.1277')),
#  (datetime.date(2019, 2, 12), Decimal('1.1316')),
#  (datetime.date(2019, 2, 13), Decimal('1.1288')),
#  (datetime.date(2019, 2, 14), Decimal('1.1284')),
#  (datetime.date(2019, 2, 15), Decimal('1.1268')),
#  (datetime.date(2019, 2, 19), Decimal('1.1328')),
#  (datetime.date(2019, 2, 21), Decimal('1.1338')),
#  (datetime.date(2019, 2, 22), Decimal('1.1342')),
#  (datetime.date(2019, 2, 25), Decimal('1.1345')),
#  (datetime.date(2019, 2, 26), Decimal('1.1374')),
#  (datetime.date(2019, 2, 27), Decimal('1.137')),
#  (datetime.date(2019, 2, 28), Decimal('1.1379')),
#  (datetime.date(2019, 3, 1), Decimal('1.1376')),
#  (datetime.date(2019, 3, 4), Decimal('1.1328')),
#  (datetime.date(2019, 3, 5), Decimal('1.13')),
#  (datetime.date(2019, 3, 6), Decimal('1.132')),
#  (datetime.date(2019, 3, 7), Decimal('1.1214')),
#  (datetime.date(2019, 3, 8), Decimal('1.1243')),
#  (datetime.date(2019, 3, 11), Decimal('1.1226')),
#  (datetime.date(2019, 3, 12), Decimal('1.1276')),
#  (datetime.date(2019, 3, 13), Decimal('1.131')),
#  (datetime.date(2019, 3, 14), Decimal('1.1304')),
#  (datetime.date(2019, 3, 15), Decimal('1.1326')),
#  (datetime.date(2019, 3, 18), Decimal('1.1337')),
#  (datetime.date(2019, 3, 19), Decimal('1.1346')),
#  (datetime.date(2019, 3, 20), Decimal('1.1352')),
#  (datetime.date(2019, 3, 21), Decimal('1.1361')),
#  (datetime.date(2019, 3, 22), Decimal('1.1282')),
#  (datetime.date(2019, 3, 25), Decimal('1.1324')),
#  (datetime.date(2019, 3, 26), Decimal('1.128')),
#  (datetime.date(2019, 3, 27), Decimal('1.125')),
#  (datetime.date(2019, 3, 28), Decimal('1.1236')),
#  (datetime.date(2019, 3, 29), Decimal('1.1228')),
#  (datetime.date(2019, 4, 1), Decimal('1.121')),
#  (datetime.date(2019, 4, 2), Decimal('1.1186')),
#  (datetime.date(2019, 4, 3), Decimal('1.1242')),
#  (datetime.date(2019, 4, 4), Decimal('1.1216')),
#  ...]

# %% [markdown]
# Now, there's one more thing we could do to make the data easier to work with. Notice how the data is just a list of tuples.

# %% [markdown]
# So to access the date in the first row, we would have to write:

# %%
forex.data[0][0]
# Out:
# datetime.date(2015, 4, 3)

# %% [markdown]
# and for the value:

# %%
forex.data[0][1]
# Out:
# Decimal('1.0990')

# %% [markdown]
# Would it not be better if we could reference those values using an attribute name, like `date` and `value`?

# %% [markdown]
# To do that we are going to create a very simple class:

# %%
class DataPoint:
    def __init__(self, date, value):
        self.date = date
        self.value = value

# %% [markdown]
# And now, instead of creating a list of tuples for our data, we are going to create a list of instances of `DataPoint`:

# %%
class Forex:
    def __init__(self, file_name):
        with open(file_name) as f:
            reader = csv.reader(f)
            
            self.headers = next(reader)
            self.data = [
                DataPoint(datetime.strptime(date, '%Y-%m-%d').date(), Decimal(value))
                for date, value in reader
                if value != '.'
            ]

# %%
forex = Forex(file_name)

# %%
forex.data[0].date
# Out:
# datetime.date(2015, 4, 3)

# %%
forex.data[0].value
# Out:
# Decimal('1.0990')

# %% [markdown]
# Let's restructure our code a bit - best practice is to try and keep functions small, including the `__init__` method.

# %% [markdown]
# So, we don't have to parse the `date` and `Decimal` in the `__init__`, we could pass the strings to the `DataPoint` class and parse them there instead.

# %%
class DataPoint:
    def __init__(self, date, value):
        self.date = datetime.strptime(date, '%Y-%m-%d').date()
        self.value = Decimal(value)
        
class Forex:
    def __init__(self, file_name):
        with open(file_name) as f:
            reader = csv.reader(f)
            self.headers = next(reader)
            self.data = [DataPoint(date, value) for date, value in reader if value != '.']

# %%
forex = Forex(file_name)

# %%
forex.data[0].date
# Out:
# datetime.date(2015, 4, 3)

# %%
forex.data[0].value
# Out:
# Decimal('1.0990')

# %% [markdown]
# Also, we don't really need the headers in our `Forex` class, since we have named our `date` and `value` attributes:

# %%
class DataPoint:
    def __init__(self, date, value):
        self.date = datetime.strptime(date, '%Y-%m-%d').date()
        self.value = Decimal(value)
        
class Forex:
    def __init__(self, file_name):
        with open(file_name) as f:
            reader = csv.reader(f)
            next(reader)  # skip header row
            self.data = [DataPoint(date, value) for date, value in reader if value != '.']

# %%
forex = Forex(file_name)

# %%
forex.data[0].date
# Out:
# datetime.date(2015, 4, 3)

# %% [markdown]
# Finally, I'd prefer not to process the file directly within the `__init__` method - I prefer to keep that method as clean as possible.

# %% [markdown]
# So, we're going to create another instance method that will do the processing. We'll call that method from inside `__init__` and assign the results to `data`:

# %%
class DataPoint:
    def __init__(self, date, value):
        self.date = datetime.strptime(date, '%Y-%m-%d').date()
        self.value = Decimal(value)
        
class Forex:
    def __init__(self, file_name):
        self.file_name = file_name
        self.data = self.process_data()  # note that we need to call process_data bound to self!
        
    def process_data(self):
        with open(self.file_name) as f:
            reader = csv.reader(f)
            next(reader)  # skip header row
            return [DataPoint(date, value) for date, value in reader if value != '.']

# %%
forex = Forex(file_name)

# %%
forex.data[0].date
# Out:
# datetime.date(2015, 4, 3)

# %% [markdown]
# We could also list out each item in data:

# %%
for item in forex.data[:5]:
    print(item.date, item.value)
# Out:
# 2015-04-03 1.0990
# 2015-04-06 1.1008
# 2015-04-07 1.0850
# 2015-04-08 1.0818
# 2015-04-09 1.0671

# %% [markdown]
# Or, we could even do this:

# %%
list(forex.data[:5])
# Out:
# [<__main__.DataPoint at 0x7fb81038a610>,
#  <__main__.DataPoint at 0x7fb81038a6d0>,
#  <__main__.DataPoint at 0x7fb81038a370>,
#  <__main__.DataPoint at 0x7fb81038a430>,
#  <__main__.DataPoint at 0x7fb81038a4c0>]

# %% [markdown]
# Well, that's not very helpful!!

# %% [markdown]
# What we're seeing here is Python's default representation of our custom object.

# %% [markdown]
# It would be much nicer if we could see printed out the date and value instead.

# %% [markdown]
# Coming up in the next set of videos!
